# %% [markdown]
# # Monopole Baseline Demo
#
# This notebook calls the modular Python package in `fem_project/src`.
#
# - Level 1 uses a 2D axisymmetric lead-field formulation.
# - Mechanism 1 moves the neuron source outward as encapsulation thickens.
# - Mechanism 2 changes the encapsulation conductivity in the FEM domain.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve().parents[0]
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src.config import AxisymmetricConfig
from src.solver import solve_axisymmetric_lead_field
from src.postprocess import evaluate_axisymmetric_recording, mechanism_source_gap
from src.plotting import plot_axisymmetric_field_map, plot_geometry_schematic

# %%
config = AxisymmetricConfig()
result = solve_axisymmetric_lead_field(
    config=config,
    t_enc=config.default_t_enc,
    sigma_enc=config.default_sigma_enc,
)
phi_elec = evaluate_axisymmetric_recording(
    result=result,
    radial_gap=mechanism_source_gap(config.baseline_gap, config.displacement_alpha, config.default_t_enc),
    source_current=config.source_current,
    z_source=config.z_source,
)
phi_elec

# %%
fig = plot_geometry_schematic(config=config, t_enc=config.default_t_enc)
fig

# %%
fig = plot_axisymmetric_field_map(result, title='Axisymmetric Monopole Recording Lead Field')
fig
